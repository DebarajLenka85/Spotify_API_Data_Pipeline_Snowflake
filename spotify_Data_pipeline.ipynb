# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="ac152f016a5e4000b10a064f0fa5072d", client_secret="aab63b8845134e5e840f017f6ec72f3f")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/0sDahzOkMWOmLXfTMf2N4N"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2025-07-21T10:58:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31yn33ajrpj5uzi6bc7u66v2w424'},
#    'href': 'https://api.spotify.com/v1/users/31yn33ajrpj5uzi6bc7u66v2w424',
#    'id': '31yn33ajrpj5uzi6bc7u66v2w424',
#    'type': 'user',
#    'uri': 'spotify:user:31yn33ajrpj5uzi6bc7u66v2w424'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2025-07-21T10:58:07Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31yn33ajrpj5uzi6bc7u66v2w424'},
#   'href': 'https://api.spotify.com/v1/users/31yn33ajrpj5uzi6bc7u66v2w424',
#   'id': '31yn33ajrpj5uzi6bc7u66v2w424',
#   'type': 'user',
#   'uri': 'spotify:user:31yn33ajrpj5uzi6bc7u66v2w424'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '14JkAa6IiFaOh5s0nMyMU9'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'KPop Demon Hunters (Soundtrack from the Netflix Film)'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)
album_df = pd.DataFrame(album_list)
album_df
# Out:
#                   album_id                                               name  \
# 0   14JkAa6IiFaOh5s0nMyMU9  KPop Demon Hunters (Soundtrack from the Netfli...
# 1   1aqg30bNvLSWgShZgX4oop                                  Man’s Best Friend
# 2   5vD5M5VW62LL78Ko8x0CVZ                                               SWAG
# 3   6xomx5ekO7qHDvDh57rZ5S                                           Ordinary
# 4   3hzoZlx2KwtvJEUl9piPWr                                               JUMP
# ..                     ...                                                ...
# 95  42rJ9A3HW7S2hWnkMNZIwk                                               ROSE
# 96  0hHXTxICTlnURMkIEfz3It                             Spin You Around (1/24)
# 97  7lxHnls3yQNl8B9bILmHj7                                          Traveller
# 98  0FYvMdfTfYJxnJnKs1wDb0                                       It's Only Me
# 99  32lGAqeVkdJxEj2iv2Q01B                                         JACKBOYS 2
#
#    release_date  total_tracks  \
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

artist_df = pd.DataFrame(artist_list).drop_duplicates().reset_index(drop=True)
artist_df
# Out:
#                  artist_id              artist_name  \
# 0   2yNNYQBChuox9A5Ka93BIn                  HUNTR/X
# 1   0RMJOzHDhAKY1o2j0W0vxY                     EJAE
# 2   0Wwji82sLA0Hcvtuak3omb              AUDREY NUNA
# 3   6U1dV7aL68N7Gb0Naq34V5                  REI AMI
# 4   7mW7Tv7NvywKKXqafZo0Lc  KPop Demon Hunters Cast
# ..                     ...                      ...
# 64  1Xyo4u8uXC1ZmMpatF05PJ               The Weeknd
# 65  699OTQXzgjhIYAHMy9RyPD            Playboi Carti
# 66  6eUKZXaKkcviH0Ku9w2n3V               Ed Sheeran
# 67  4YLtscXsxbVgi031ovDDdh          Chris Stapleton
# 68  2qoQgPAilErOKCwE2Y8wOG                 GloRilla
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/2yNNYQBChuo...
# 1   https://api.spotify.com/v1/artists/0RMJOzHDhAK...
# 2   https://api.spotify.com/v1/artists/0Wwji82sLA0...
# 3   https://api.spotify.com/v1/artists/6U1dV7aL68N...
# 4   https://api.spotify.com/v1/artists/7mW7Tv7Nvyw...
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)
song_df = pd.DataFrame(song_list).drop_duplicates().reset_index(drop=True)
song_df
# Out:
#                    song_id               song_name  duration_ms  \
# 0   1CPZ5BxNNd0n0nF4Orb9JS                  Golden       194607
# 1   42VUCXerQ5qTr4Qp6PhKo4                   Tears       160183
# 2   5BZsQlgw21vDOAjoqkNgKb                 DAISIES       176453
# 3   6qqrTXSdwiJaq8SO0X2lSe                Ordinary       186964
# 4   5H1sKFMzDeMtXwND3V6hRY                    JUMP       164718
# ..                     ...                     ...          ...
# 95  20VZXnRzvcS0qVMOThjjmM                   Tiger       190080
# 96  47Xj8eIAp7hYOOqArmkqZE  Spin You Around (1/24)       209427
# 97  3fqwjXwUGN6vbzIwvyFMhx       Tennessee Whiskey       293293
# 98  31lopd32BkJBTSgYE16c5e             In A Minute       200470
# 99  4lUAlhQOVzhitQKjxrHVny                   SHYNE       193183
#
#                                                   url  popularity  \
# 0   https://open.spotify.com/track/1CPZ5BxNNd0n0nF...         100
# ...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      69 non-null     object
#  1   name          69 non-null     object
#  2   release_date  69 non-null     datetime64[ns]
#  3   total_tracks  69 non-null     int64
#  4   url           69 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69 entries, 0 to 152
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     69 non-null     object
#  1   artist_name   69 non-null     object
#  2   external_url  69 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id song_name  duration_ms  \
# 0  1CPZ5BxNNd0n0nF4Orb9JS    Golden       194607
# 1  42VUCXerQ5qTr4Qp6PhKo4     Tears       160183
# 2  5BZsQlgw21vDOAjoqkNgKb   DAISIES       176453
# 3  6qqrTXSdwiJaq8SO0X2lSe  Ordinary       186964
# 4  5H1sKFMzDeMtXwND3V6hRY      JUMP       164718
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/1CPZ5BxNNd0n0nF...         100
# 1  https://open.spotify.com/track/42VUCXerQ5qTr4Q...          94
# 2  https://open.spotify.com/track/5BZsQlgw21vDOAj...          93
# 3  https://open.spotify.com/track/6qqrTXSdwiJaq8S...          91
# 4  https://open.spotify.com/track/5H1sKFMzDeMtXwN...          92
#
#              song_added                album_id               artist_id
# 0  2025-07-21T10:58:07Z  14JkAa6IiFaOh5s0nMyMU9  7mW7Tv7NvywKKXqafZo0Lc
# 1  2025-09-02T20:00:33Z  1aqg30bNvLSWgShZgX4oop  74KM79TiuVKeVCqs8QtB0B
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      69 non-null     object
#  1   name          69 non-null     object
#  2   release_date  69 non-null     datetime64[ns]
#  3   total_tracks  69 non-null     int64
#  4   url           69 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
